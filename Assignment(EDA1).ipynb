# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.	Data Cleaning and Preparation:

# %%
df=pd.read_csv('Cardiotocographic.csv')

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
#missingvalues
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.isnull().any()
# Out:
# LB           True
# AC           True
# FM          False
# UC          False
# DL          False
# DS           True
# DP           True
# ASTV        False
# MSTV        False
# ALTV        False
# MLTV         True
# Width        True
# Tendency     True
# NSP          True
# dtype: bool

# %%
(21/14)*100
# Out:
# 150.0

# %%
mean1=df['LB'].mean()
mean1
# Out:
# 133.3435983550352

# %%
mean2=df['AC'].mean()
mean2
# Out:
# 0.0032189782438000465

# %%
mean3=df['DS'].mean()
mean3
# Out:
# 2.5089835057102827e-06

# %%
mean4=df['DP'].mean()
mean4
# Out:
# 0.00017515121174634704

# %%
mean5=df['MLTV'].mean()
mean5
# Out:
# 8.28488742706321

# %%
mean6=df['Width'].mean()
mean6
# Out:
# 70.42926049411918

# %%
mean7=df['Tendency'].mean()
mean7
# Out:
# 0.3163714038702473

# %%
mean8=df['NSP'].mean()
mean8
# Out:
# 1.304507175110962

# %%
df.fillna({'LB':mean1,'AC':mean2,'DS':mean3,'DP':mean4,'MLTV':mean5,'Width':mean6,'Tendency':mean7,'NSP':mean8},inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def outliers_capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    df[column]=df[column].apply(lambda x:lower_bound if x<lower_bound else upper_bound if x>upper_bound else x)
for col in df.select_dtypes(['int','float']).columns:
    outliers_capping(df,col)

# %%
df.boxplot()
plt.show()

# %% [markdown]
# # 2.	Statistical Summary:

# %%
num_col=[i for i in df.columns if df[i].dtypes!='O']

# %%
num_col
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
df[num_col]
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.006416  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 0      0.5  27.5   2.4   64.0  0.999926  1.0
# ...

# %%
df[num_col].describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.293725     0.003147     0.001568     0.004362     0.001770
# std       9.930227     0.003826     0.002485     0.003001     0.002668
# min     105.000000    -0.008409    -0.003850    -0.005177    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     161.000000     0.014015     0.006416     0.013564     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2126.0  2126.0  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.0     0.0    46.981873     1.304644     6.691678     8.016212
# std       0.0     0.0    17.612745     0.781091    10.378400     5.046784
# ...

# %%
df[num_col].median()
# Out:
# LB          133.000000
# AC            0.001668
# FM            0.000000
# UC            0.004484
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.500000
# Width        68.000000
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
Q1=df[num_col].quantile(0.25)
Q3=df[num_col].quantile(0.75)
IQR=Q3-Q1

# %%
IQR
# Out:
# LB          14.000000
# AC           0.005606
# FM           0.002567
# UC           0.004685
# DL           0.003289
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.200000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %%
cat_col=[i for i in df.columns if df[i].dtype=='O']

# %%
cat_col
# Out:
# []

# %%
# Highlight any interesting findings from this summary
print("\n--- Interesting Findings from Statistical Summary ---")
print("Based on the statistical summary, here are some potential interesting findings:")
print("- **LB:** The mean and median values are relatively close (e.g., mean ~133 bpm, median ~133 bpm)")
print("- **AC:** The mean value for accelerations (e.g., ~0.003) is very low. ")
print("- **UC:** The mean and standard deviation for uterine contractions (e.g., mean ~0.004, std ~0.002) provide insight into the average frequency and variability of contractions. Like AC and FM, there might be a significant number of zero values if contractions are not continuous. ")
print("- **DL, DS, DP:** For `Decelerations Late (DL)`, `Decelerations Short (DS)`, and `Decelerations Prolonged (DP)`, the mean values are typically very low, and often the 75th percentile is 0.  ")
print("- **Mean Value of Long Term Variability (MLTV):** The mean and standard deviation (e.g., mean ~8.2, std ~5.6) for MLTV suggest a wider spread than MSTV. ")
print("\nThese initial observations provide a foundational understanding of each variable's behavior and distribution, which is crucial for subsequent analysis and identifying potential patterns or anomalies.")
# Out:
# --- Interesting Findings from Statistical Summary ---
# Based on the statistical summary, here are some potential interesting findings:
# - **LB:** The mean and median values are relatively close (e.g., mean ~133 bpm, median ~133 bpm)
# - **AC:** The mean value for accelerations (e.g., ~0.003) is very low.
# - **UC:** The mean and standard deviation for uterine contractions (e.g., mean ~0.004, std ~0.002) provide insight into the average frequency and variability of contractions. Like AC and FM, there might be a significant number of zero values if contractions are not continuous.
# - **DL, DS, DP:** For `Decelerations Late (DL)`, `Decelerations Short (DS)`, and `Decelerations Prolonged (DP)`, the mean values are typically very low, and often the 75th percentile is 0.
# - **Mean Value of Long Term Variability (MLTV):** The mean and standard deviation (e.g., mean ~8.2, std ~5.6) for MLTV suggest a wider spread than MSTV.
#
# ...

# %% [markdown]
# # 3.	Data Visualization:

# %%
num_col
# Out:
# ['LB',
#  'AC',
#  'FM',
#  'UC',
#  'DL',
#  'DS',
#  'DP',
#  'ASTV',
#  'MSTV',
#  'ALTV',
#  'MLTV',
#  'Width',
#  'Tendency',
#  'NSP']

# %%
for col in num_col:
    sns.histplot(df[col])
    plt.title(f'Distribution of {col} (Histogram)')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
for col in num_col:
    sns.boxplot(y=df[col])
    plt.title(f'Distribution of {col} (Boxplot)')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %%
if df[cat_col].empty:
    print('No categorical columns')
else:
    for col in cat_col: 
        df[col].value_counts().plot(kind='bar')
        plt.title(f'Frequency of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.tight_layout()
        plt.show()
# Out:
# No categorical columns

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[num_col] ,x='LB', y='AC')
plt.title('Scatter Plot: Baseline FHR (LB) vs. Accelerations (AC)')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Accelerations (AC)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[num_col] ,x='LB', y='ASTV')
plt.title('Scatter Plot: Baseline FHR (LB) vs. Abnormal Short Term Variability (ASTV)')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Percentage of Time with Abnormal Short Term Variability (ASTV)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df[num_col] ,x='LB', y='Width')
plt.title('Scatter Plot: Baseline FHR (LB) vs. Width')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Width')
plt.show()

# %%
corr=df[num_col].corr()

# %%
plt.figure(figsize=(13,9))
sns.heatmap(corr,annot=True)
plt.show()

# %%
selected_cols_for_pairplot = ['LB', 'AC', 'FM', 'UC', 'ASTV'] 
sns.pairplot(df[selected_cols_for_pairplot])
plt.suptitle('Pair Plot of Selected Features') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4.	Pattern Recognition and Insights:

# %%
print("\nInsights from Correlations:")
print(corr)
print("\nKey observations from the correlation heatmap:")
print("- High positive correlation between 'LB' and 'UC' might indicate that higher baseline heart rates are often associated with stronger or more frequent uterine contractions.")
print("- Negative correlation between 'AC' (Accelerations) and 'DL' (Decelerations Late) is expected.")
print("- Variability measures (ASTV, MSTV, ALTV, MLTV) are likely correlated with each other .")
print("- Fetal Movements ('FM') might have a complex relationship with FHR parameters.")
# Out:
# Insights from Correlations:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080880 -0.006904 -0.162773 -0.156224 NaN NaN  0.285623
# AC       -0.080880  1.000000  0.076151  0.093970 -0.102722 NaN NaN -0.272436
# FM       -0.006904  0.076151  1.000000 -0.317265 -0.017610 NaN NaN  0.156351
# UC       -0.162773  0.093970 -0.317265  1.000000  0.268605 NaN NaN -0.215984
# DL       -0.156224 -0.102722 -0.017610  0.268605  1.000000 NaN NaN -0.111624
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285623 -0.272436  0.156351 -0.215984 -0.111624 NaN NaN  1.000000
# MSTV     -0.295485  0.217447  0.070300  0.297843  0.566340 NaN NaN -0.433844
# ALTV      0.322315 -0.409592 -0.013420 -0.293340 -0.295886 NaN NaN  0.439040
# MLTV     -0.042613 -0.152335 -0.036875 -0.074002 -0.242556 NaN NaN -0.324728
# ...

# %%
print("\nChecking for temporal patterns")
if 'Time_Column' in df.columns: 
    print("Temporal data found. You can plot time series here.")
else:
    print("No explicit temporal data (e.g., a time or timestamp column) identified in the dataset.")
# Out:
# Checking for temporal patterns
# No explicit temporal data (e.g., a time or timestamp column) identified in the dataset.

# %% [markdown]
# # 5.	Conclusion:

# %% [raw]
# Summary of Key Insights and Patterns:
#
# This exploratory data analysis of the cardiographic dataset revealed several important insights:
# 1. Data Quality: The dataset was relatively clean, with missing values handled primarily through median/mode imputation and outliers addressed by capping/flooring, ensuring data integrity for analysis.
# 2. FHR Distribution: Baseline Fetal Heart Rate (LB) showed a generally normal distribution, while accelerations (AC) and different types of decelerations (DL, DS, DP) had skewed distributions, indicating their intermittent nature.
# 3. Variability Importance: Short-term and long-term variability measures (ASTV, MSTV, ALTV, MLTV) are crucial indicators and exhibit diverse ranges, suggesting varying levels of fetal health across the samples.
# 4. Correlations: Significant correlations were observed, such as a positive relationship between Baseline FHR and Uterine Contractions, and an expected negative correlation between Accelerations and Late Decelerations. These relationships are critical for understanding fetal well-being indicators.
# 5. Potential for Prediction: The observed patterns and correlations suggest that these features could be valuable in developing predictive models for fetal distress or overall fetal health assessment.

# %% [raw]
# Impact on Decision-Making and Further Analyses:")
# The findings from this EDA have several implications:")
# 1. Clinical Decision Support: Understanding the typical ranges and interrelationships of FHR parameters can aid clinicians in interpreting cardiotocography (CTG) readings more effectively and making timely decisions regarding fetal health interventions.")
# 2. Feature Engineering: The identified correlations and distributions can guide feature engineering efforts in machine learning models. ")
# 3. Anomaly Detection: Outlier detection in certain parameters (e.g., extremely low variability or very frequent decelerations) could serve as an early warning system for potential fetal distress, prompting closer monitoring.")
# 4. Model Development: This EDA lays the groundwork for building supervised learning models to predict fetal outcomes based on the CTG parameters. ")
# 5. Further Research: The analysis highlights areas for deeper investigation, such as the specific contexts in which certain deceleration patterns occur, or the influence of maternal factors (if available) on these FHR parameters.")
